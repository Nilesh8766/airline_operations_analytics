# %%
from pathlib import Path
import zipfile
import numpy as np
import pandas as pd
import sys

# %%
PROJECT_PATH = Path.cwd().parent
sys.path.insert(0, str(PROJECT_PATH))

# %%
from data_loader import get_project_path

# %%
PROJECT_PATH = get_project_path()
# Out:
# Project Path D:\arc\Python\Python Projects\airline_operations_analytics

# %%
from data_loader import create_project_folders

# %%
RAW_PATH, DOCUMENTATION_PATH = create_project_folders(PROJECT_PATH)
# Out:
# Raw_Path D:\arc\Python\Python Projects\airline_operations_analytics\01_Raw_Data
# Documentation_Path D:\arc\Python\Python Projects\airline_operations_analytics\02_Documentation

# %%
from data_loader import create_year_folders

# %%
RAW_2024_PATH, RAW_2025_PATH = create_year_folders(RAW_PATH)
# Out:
# Raw_2024_Path D:\arc\Python\Python Projects\airline_operations_analytics\01_Raw_Data\2024
# Raw_2025_Path D:\arc\Python\Python Projects\airline_operations_analytics\01_Raw_Data\2025

# %%
from data_loader import inspect_zip_files

# %%
zip_files = inspect_zip_files(RAW_2024_PATH)
# Out:
# Total Zip File: 12
# File Name: On_Time_Reporting_Carrier_On_Time_Performance_1987_present_2024_1.zip
# File Size:  26.3 MB
# File Location D:\arc\Python\Python Projects\airline_operations_analytics\01_Raw_Data\2024\On_Time_Reporting_Carrier_On_Time_Performance_1987_present_2024_1.zip
# File Name: On_Time_Reporting_Carrier_On_Time_Performance_1987_present_2024_10.zip
# File Size:  28.06 MB
# File Location D:\arc\Python\Python Projects\airline_operations_analytics\01_Raw_Data\2024\On_Time_Reporting_Carrier_On_Time_Performance_1987_present_2024_10.zip
# File Name: On_Time_Reporting_Carrier_On_Time_Performance_1987_present_2024_11.zip
# File Size:  26.85 MB
# File Location D:\arc\Python\Python Projects\airline_operations_analytics\01_Raw_Data\2024\On_Time_Reporting_Carrier_On_Time_Performance_1987_present_2024_11.zip
# File Name: On_Time_Reporting_Carrier_On_Time_Performance_1987_present_2024_12.zip
# File Size:  28.75 MB
# ...

# %%
from data_loader import inspect_zip_contents

# %%
zip_file, files_inside_zip = inspect_zip_contents(zip_files, 1)
# Out:
# On_Time_Reporting_Carrier_On_Time_Performance_(1987_present)_2024_10.csv
# readme.html

# %%
from data_loader import create_extract_folder

# %%
EXTRACT_PATH = create_extract_folder(RAW_2025_PATH, "January")
# Out:
# Extract_Path D:\arc\Python\Python Projects\airline_operations_analytics\01_Raw_Data\2025\January

# %%
from data_loader import extract_zip_file

# %%
extract_zip_file(zip_file, EXTRACT_PATH)

# %%
from data_loader import find_csv_files

# %%
csv_files = find_csv_files(EXTRACT_PATH)
# Out:
# d:\arc\Python\Python Projects\airline_operations_analytics\01_Raw_Data\2025\January\On_Time_Reporting_Carrier_On_Time_Performance_(1987_present)_2024_10.csv

# %%
from data_loader import load_csv_file

# %%
df = load_csv_file(csv_files)

# %%
# Out:
#         Year  Quarter  Month  DayofMonth  DayOfWeek  FlightDate  \
# 615495  2024        4     10          29          2  2024-10-29
# 615496  2024        4     10          29          2  2024-10-29
#
#        Reporting_Airline  DOT_ID_Reporting_Airline  \
# 615495                UA                     19977
# 615496                UA                     19977
#
#        IATA_CODE_Reporting_Airline Tail_Number  ...  Div4TailNum  Div5Airport  \
# 615495                          UA      N38479  ...          NaN          NaN
# 615496                          UA      N13113  ...          NaN          NaN
#
#         Div5AirportID  Div5AirportSeqID Div5WheelsOn Div5TotalGTime  \
# 615495            NaN               NaN          NaN            NaN
# 615496            NaN               NaN          NaN            NaN
#
#        Div5LongestGTime  Div5WheelsOff Div5TailNum  Unnamed: 109
# 615495              NaN            NaN         NaN           NaN
# ...
